# %%
import pandas as pd

# %%
df=pd.read_table('pharma1.txt')
# Out:
# C:\Users\y34v00\AppData\Local\Temp\ipykernel_28228\2530308194.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_table('pharma1.txt')

# %%
df.columns
# Out:
# Index(['areaid', 'areaname', 'districtid', 'districtname', 'areaid0',
#        'areaname0', 'districtid0', 'districtname0', 'pharmagroup',
#        'clientdunsno', 'customerlocationname', 'custcol_8', 'parentptsdunsno',
#        'custcol_6', 'parentshipperlocationname', 'productcode',
#        'producttypedesc', 'weekid', 'weekdesc', 'monthid', 'monthdesc',
#        'mailclasscode', 'svcstddaytimecode', 'mailclasssrvcstddesc',
#        'ontimevolume', 'totalcount', 'failedcount'],
#       dtype='object')

# %%
df
# Out:
#         areaid  areaname  districtid    districtname  areaid0 areaname0  \
# 0            7  SOUTHERN        1497       FLORIDA 1        7  SOUTHERN
# 1           10   CENTRAL          72           KS-MO       10   CENTRAL
# 2            2  ATLANTIC           9           MA-RI        2  ATLANTIC
# 3           10   CENTRAL          72           KS-MO       10   CENTRAL
# 4            5   WESTPAC        1081           AZ-NM        5   WESTPAC
# ...        ...       ...         ...             ...      ...       ...
# 363667      10   CENTRAL          72           KS-MO        5   WESTPAC
# 363668      10   CENTRAL          16          OHIO 2       10   CENTRAL
# 363669       2  ATLANTIC        2294  NORTH CAROLINA        7  SOUTHERN
# 363670       5   WESTPAC          73      WASHINGTON        5   WESTPAC
# 363671       2  ATLANTIC        2294  NORTH CAROLINA        2  ATLANTIC
#
#         districtid0 districtname0       pharmagroup  clientdunsno  ... weekid  \
# 0              1497     FLORIDA 1               HDP     902293986  ...   5568
# 1                72         KS-MO   OPTUM RX OP_HDP     902746684  ...   5602
# 2                 9         MA-RI               HDP     902293986  ...   5597
# 3                16        OHIO 2  CMOP LEAVENWORTH     901581567  ...   5566
# 4              1080         NV-UT            HUMANA     931508577  ...   5569
# ...             ...           ...               ...           ...  ...    ...
# 363667           38  CALIFORNIA 5   OPTUM RX OP_HDP     902746685  ...   5568
# 363668           16        OHIO 2           INGENIO     902372651  ...   5584
# 363669         1497     FLORIDA 1   OPTUM RX CH_HDP     902746633  ...   5566
# 363670           63  CALIFORNIA 6   OPTUM RX WV_HDP     902746732  ...   5604
# 363671           44      MARYLAND   OPTUM RX CH_HDP     902746628  ...   5595
#
#           weekdesc  monthid monthdesc mailclasscode svcstddaytimecode  \
# 0       2022-01-08     1289  JAN 2022            PM              2D
# 1       2022-09-03     1297  SEP 2022            FC              2D
# 2       2022-07-30     1296  AUG 2022            FC              2D
# 3       2021-12-25     1288  DEC 2021            PM              3D
# 4       2022-01-15     1289  JAN 2022            PM              2D
# ...            ...      ...       ...           ...               ...
# 363667  2022-01-08     1289  JAN 2022            PM              2D
# 363668  2022-04-30     1293  MAY 2022            FC              2D
# 363669  2021-12-25     1288  DEC 2021            PM              3D
# 363670  2022-09-17     1297  SEP 2022            FC              3D
# 363671  2022-07-16     1295  JUL 2022            FC              3D
#
#          mailclasssrvcstddesc  ontimevolume totalcount  failedcount
# 0       Priority Mail - 2 Day            14         14            0
# 1         First Class - 2 Day           337        357           20
# 2         First Class - 2 Day             1          1            0
# 3       Priority Mail - 3 Day             7          7            0
# 4       Priority Mail - 2 Day           416        420            4
# ...                       ...           ...        ...          ...
# 363667  Priority Mail - 2 Day             1          1            0
# 363668    First Class - 2 Day             1          1            0
# 363669  Priority Mail - 3 Day             2          2            0
# 363670    First Class - 3 Day           178        180            2
# 363671    First Class - 3 Day           401        433           32
#
# [363672 rows x 27 columns]

# %%
df.areaname.value_counts()
# Out:
# CENTRAL     124557
# SOUTHERN     86605
# WESTPAC      79178
# ATLANTIC     73332
# Name: areaname, dtype: int64

# %%
df['weekdesc']=pd.to_datetime(df['weekdesc'])

# %%
df.sort_values(by='weekdesc')
# Out:
#         areaid  areaname  districtid    districtname  areaid0 areaname0  \
# 63354        2  ATLANTIC          74        VIRGINIA       10   CENTRAL
# 325473      10   CENTRAL          14      ILLINOIS 1        5   WESTPAC
# 258675      10   CENTRAL          72           KS-MO       10   CENTRAL
# 123367       5   WESTPAC          73      WASHINGTON        5   WESTPAC
# 289989      10   CENTRAL          72           KS-MO        7  SOUTHERN
# ...        ...       ...         ...             ...      ...       ...
# 32073        2  ATLANTIC        2294  NORTH CAROLINA       10   CENTRAL
# 297606       5   WESTPAC        1081           AZ-NM       10   CENTRAL
# 94035        2  ATLANTIC        2294  NORTH CAROLINA        7  SOUTHERN
# 214274       2  ATLANTIC        1317      NEW JERSEY        2  ATLANTIC
# 80581        7  SOUTHERN        1482       FLORIDA 2        7  SOUTHERN
#
#         districtid0   districtname0                           pharmagroup  \
# 63354            31      MICHIGAN 2  KAISER PERMANENTE - MAS REGION - EVS
# 325473           64    CALIFORNIA 1                                   CVS
# 258675           55           MN-ND                      CMOP LEAVENWORTH
# 123367           63    CALIFORNIA 6                       OPTUM RX WV_HDP
# 289989         1084  SOUTH CAROLINA                                   HDP
# ...             ...             ...                                   ...
# 32073            14      ILLINOIS 1                       OPTUM RX CH_HDP
# 297606           16          OHIO 2                                HUMANA
# 94035          1084  SOUTH CAROLINA                       OPTUM RX CH_HDP
# 214274            1      NEW YORK 3                                   HDP
# 80581          1482       FLORIDA 2                        OPTUMRX OV_HDP
#
#         clientdunsno  ... weekid   weekdesc  monthid monthdesc mailclasscode  \
# 63354      902072113  ...   5556 2021-10-16     1286  OCT 2021            PM
# 325473     999999194  ...   5556 2021-10-16     1286  OCT 2021            PM
# 258675     901581567  ...   5556 2021-10-16     1286  OCT 2021            PM
# 123367     902746734  ...   5556 2021-10-16     1286  OCT 2021            FC
# 289989     902205142  ...   5556 2021-10-16     1286  OCT 2021            PM
# ...              ...  ...    ...        ...      ...       ...           ...
# 32073      902746631  ...   5608 2022-10-15     1298  OCT 2022            PM
# 297606     931508577  ...   5608 2022-10-15     1298  OCT 2022            PM
# 94035      902746630  ...   5608 2022-10-15     1298  OCT 2022            FC
# 214274     902293958  ...   5608 2022-10-15     1298  OCT 2022            PM
# 80581      902746691  ...   5608 2022-10-15     1298  OCT 2022            PM
#
#        svcstddaytimecode   mailclasssrvcstddesc  ontimevolume totalcount  \
# 63354               2D    Priority Mail - 2 Day             1          1
# 325473              2D    Priority Mail - 2 Day             8         10
# 258675              2D    Priority Mail - 2 Day             7          8
# 123367              3D      First Class - 3 Day             5          6
# 289989              2D    Priority Mail - 2 Day             1          1
# ...                  ...                    ...           ...        ...
# 32073               2D    Priority Mail - 2 Day            11         11
# 297606              2D    Priority Mail - 2 Day            14         14
# 94035               3D      First Class - 3 Day             1          1
# 214274              2D    Priority Mail - 2 Day            17         18
# 80581               1D    Priority Mail - 1 Day             1          1
#
#         failedcount
# 63354             0
# 325473            2
# 258675            1
# 123367            1
# 289989            0
# ...             ...
# 32073             0
# 297606            0
# 94035             0
# 214274            1
# 80581             0
#
# [363672 rows x 27 columns]

# %%
df.head(10000).to_csv('df2.csv')
